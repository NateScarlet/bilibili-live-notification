# %%
import bilibili_live_notification.room

# %%
await bilibili_live_notification.room.get(rid=298626)
# Out:
# {'name': 'NateScarlet',
#  'title': '测试2',
#  'url': 'https://live.bilibili.com/298626',
#  'data': {'room_info': {'uid': 1962,
#    'room_id': 298626,
#    'short_id': 0,
#    'title': '测试2',
#    'cover': 'http://i0.hdslb.com/bfs/live/b826e74892bfa7a13be2a40e8612057d63e27fad.png',
#    'tags': '',
#    'background': 'https://i0.hdslb.com/bfs/live/2836bb7b84c792e2c6aadfd4d1cce13484775fa3.jpg',
#    'description': '单机、联机合作、原神、崩坏\n\n出没时间\n工作日\n19:30~22:30\n休息日\n12:00~22:30',
#    'live_status': 0,
#    'live_start_time': 0,
#    'live_screen_type': 0,
#    'lock_status': 0,
#    'lock_time': 0,
#    'hidden_status': 0,
#    'hidden_time': 0,
#    'area_id': 40,
#    'area_name': '崩坏3',
#    'parent_area_id': 3,
#    'parent_area_name': '手游',
#    'keyframe': 'http://i0.hdslb.com/bfs/live-key-frame/keyframe04032049000000298626v9fcsb.jpg',
#    'special_type': 0,
#    'up_session': '0',
#    'pk_status': 0,
#    'is_studio': False,
# ...
