# %%
import bilibili_api

# %%
bilibili_api.live.get_room_info(298626)
# Out:
# {'room_info': {'uid': 1962,
#   'room_id': 298626,
#   'short_id': 0,
#   'title': 'RAFT',
#   'cover': 'http://i0.hdslb.com/bfs/live/b826e74892bfa7a13be2a40e8612057d63e27fad.png',
#   'tags': '炉石传说',
#   'background': 'https://i0.hdslb.com/bfs/live/2836bb7b84c792e2c6aadfd4d1cce13484775fa3.jpg',
#   'description': '<p>单机、联机合作、炉石</p>\n<p>\xa0</p>\n<table><tr>\n出没时间\n</tr><tr><td>工作日</td>\n<td>19:30~22:30</td>\n</tr><tr><td>休息日</td>\n<td>12:00~22:30</td>\n</tr></table>',
#   'live_status': 0,
#   'live_start_time': 0,
#   'live_screen_type': 0,
#   'lock_status': 0,
#   'lock_time': 0,
#   'hidden_status': 0,
#   'hidden_time': 0,
#   'area_id': 235,
#   'area_name': '其他单机',
#   'parent_area_id': 6,
#   'parent_area_name': '单机游戏',
#   'keyframe': 'http://i0.hdslb.com/bfs/live/keyframe1121192600000029862638wzbz.jpg',
#   'special_type': 0,
#   'up_session': '0',
#   'pk_status': 0,
#   'is_studio': False,
#   'pendants': {'frame': {'name': '', 'value': '', 'desc': ''}},
# ...
